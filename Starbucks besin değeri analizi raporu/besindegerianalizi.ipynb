# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt # Veri görselleştirme kısmı
import seaborn as sns

# %%
sns.set_style("darkgrid") # Tema seçimi yapıldı.

# %%
df =pd.read_csv("starbucks.csv",index_col=0) # İndex düzgün başlamadığı için index_col = 0 ibaresini koyduk.

# %%
df.head(10) # Verinin yapısını incelemek için açtık.
# Out:
#                            item  calories   fat  carb  fiber  protein    type
# 1                  8-Grain Roll       350   8.0    67      5       10  bakery
# 2             Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                 Apple Fritter       420  20.0    59      0        5  bakery
# 4               Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5   Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery
# 6             Blueberry Oat Bar       370  14.0    47      5        6  bakery
# 7               Blueberry Scone       460  22.0    61      2        7  bakery
# 8    Bountiful Blueberry Muffin       370  14.0    55      0        6  bakery
# 9             Butter Croissant        310  18.0    32      0        5  bakery
# 10                Cheese Danish       420  25.0    39      0        7  bakery

# %%
df.info() # Verilerimizin türünü incelemek için kullandığımız fonksiyon.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 1 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe() #Sütunların adedi ortalaması vb özellikleri görmemizi sağlayan fonksiyondur.
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df["item"].nunique() # Kaç farklı ürün olduğunu inceledik.
# Out:
# 77

# %%
df["item"].unique() # Bu columndaki değerlerin isimlerini görüntüledik. ( unique olduğu için aynı ürün varsa tekrar göstermez.)
# Out:
# array(['8-Grain Roll', 'Apple Bran Muffin', 'Apple Fritter',
#        'Banana Nut Loaf', 'Birthday Cake Mini Doughnut',
#        'Blueberry Oat Bar', 'Blueberry Scone',
#        'Bountiful Blueberry Muffin', 'Butter Croissant ', 'Cheese Danish',
#        'Chocolate Chunk Cookie', 'Chocolate Cinnamon Bread',
#        'Chocolate Croissant', 'Chocolate Old-Fashioned Doughnut',
#        'Chonga Bagel', 'Cinnamon Chip Scone', 'Cranberry Orange Scone',
#        'Double Chocolate Brownie', 'Double Fudge Mini Doughnut',
#        'Everything with Cheese Bagel', 'Ginger Molasses Cookie',
#        'Iced Lemon Pound Cake', 'Mallorca Sweet Bread',
#        'Maple Oat Pecan Scone ', 'Marble Pound Cake',
#        'Marshmallow Dream Bar', 'Morning Bun', 'Multigrain Bagel',
#        'Old-Fashioned Glazed Doughnut', 'Outrageous Oatmeal Cookie',
#        'Petite Vanilla Bean Scone', 'Plain Bagel', 'Pumpkin Bread',
#        'Pumpkin Scone ', 'Raspberry Scone', 'Raspberry Swirl Pound Cake',
# ...

# %%
df["type"].unique() #Yukarıdaki örnekte verdiğim bilgi üzerine çok sayıda satırda bulunmasına rağmen sadece bir defa onun ismini gösterdi.
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
df.groupby("type")["item"].count() # typelara ait kaç adet item olduğunu görüntüledik.
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %% [markdown]
# ## Çizgi Grafiği

# %%
df.groupby("type")["item"].count().plot()
plt.title("Ürün türleri") #Tabloya başlık atmamızı sağlar.
plt.text(0.,50,"Ürün kategori yelpazesi.",bbox=dict(facecolor="yellow",alpha=0.5)) # Bizim tablo üstüne yazı eklememizi sağlar.
plt.show()

# %% [markdown]
# ## Sütun Grafiği

# %%
sns.countplot(x="type" ,hue="type",data=df,palette="Set1") #hue ekleme sebebi uyarı vermesi (palette kullanıldığı için) başka bir kategorik değişkenle ilişkilendirmeye yarar.
plt.title("Kategori Sayıları")
plt.show()

# %% [markdown]
# ## Kategorisine göre içerik hesaplamaları

# %%
sns.catplot(kind="bar",x="type",hue="type",y="calories",data=df,palette="Set1")
plt.title("Kalori değerleri")
plt.show()

# %%
sns.catplot(kind="bar",x="type",hue="type",y="protein",data=df,palette="Set1")
plt.title("Protein değerleri")
plt.show()

# %%
sns.catplot(kind="bar",x="type",hue="type",y="carb",data=df,palette="Set1")
plt.title("Karbonhidrat değerleri")
plt.show()

# %%
sns.catplot(kind="bar",x="type",hue="type",y="fiber",data=df,palette="Set1")
plt.title("Lif değerleri")
plt.show()

# %%
numeric_columns = df.select_dtypes(include='number') #df.corr() ile korelasyon alacaktık ancak 8-Grain Roll u string aldıladığı için bu düzenleme ile tablodan sadece sayısal sütunları seçtim.
corr_matrix = numeric_columns.corr()
corr_matrix
# Out:
#           calories       fat      carb     fiber   protein
# calories  1.000000  0.758682  0.674999  0.260645  0.410398
# fat       0.758682  1.000000  0.144547 -0.028549  0.223470
# carb      0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber     0.260645 -0.028549  0.213044  1.000000  0.488564
# protein   0.410398  0.223470 -0.050789  0.488564  1.000000

# %% [markdown]
# ## Haritalama ile korelasyon verisi gösterimi

# %%
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Kalori ve yağ arasında bir saçılım grafiği

# %%
plt.title("Kalori ve yağ kolerasyonu")
sns.scatterplot(x="calories",y="fat",data=df,s=30,edgecolor="red") #Burada s nokta boyutu edgecolor ise noktaların kenar rengini ayarlar.
# Out:
# <Axes: title={'center': 'Kalori ve yağ kolerasyonu'}, xlabel='calories', ylabel='fat'>

# %% [markdown]
# ## Yiyecek içeceklerin besin değeri dağılımı

# %%
sns.displot(x="calories",data=df,color="red",kde=True)
plt.title("Kalori grafiği")
plt.show()

# %%
sns.displot(x="protein",data=df,color="green",kde=True)
plt.title("Protein grafiği")
plt.show()

# %%
sns.displot(x="fat",data=df,color="purple",kde=True)
plt.title("Yağ grafiği")
plt.show()

# %%
sns.displot(x="carb",data=df,color="violet",kde=True)
plt.title("Karbonhidrat grafiği")
plt.show()

# %% [markdown]
# ## Ürünün türünü besin değerine göre tahmin etme

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x=df[["calories","fat","carb","fiber","protein"]]
y=df["type"]

# %%
x_train,xtest,y_train,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=DecisionTreeClassifier() #Bu kısımda modelimizi eğittik.
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred= model.predict(xtest)

# %%
accuracy=accuracy_score(ytest,y_pred)

# %%
print("Doğruluk:",accuracy) #Doğruluk oranını gözlemledik.
# Out:
# Doğruluk: 0.75

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 1                            8-Grain Roll       350   8.0    67      5
# 2                       Apple Bran Muffin       350   9.0    64      7
# 3                           Apple Fritter       420  20.0    59      0
# 4                         Banana Nut Loaf       490  19.0    75      4
# 5             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 73        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 74                Turkey & Swiss Sandwich       390  13.0    36      2
# 75             Greek Yogurt Honey Parfait       300  12.0    44      0
# 76         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 1        10    bakery
# 2         6    bakery
# 3         5    bakery
# ...

# %%
prediction=model.predict([[250,2,40,7,9]]) #Burada tahmin yaptırıyoruz.
print(f"Ürün {prediction} kategorisinde olabilir.")
# Out:
# Ürün ['bakery'] kategorisinde olabilir.
# c:\Users\Serdar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Tahmin durumunu ağaçlandırma

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(15,10))
plot_tree(model,feature_names=x.columns,class_names=model.classes_,filled=True)
plt.show()
